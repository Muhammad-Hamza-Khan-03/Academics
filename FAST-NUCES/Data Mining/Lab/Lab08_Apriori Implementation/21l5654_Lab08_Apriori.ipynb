# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=92bea991a857e0d2942cbd43e441f7dccd1d15d38cafac618b112b00005cdddf
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
df = pd.read_csv('/content/groceries_dataset.csv')

# %%
df.shape
# Out:
# (9835, 32)

# %%
records = []
for i in range(0, 9835):
    records.append([str(df.values[i,u]) for u in range(0, 32)])

# %%
rules = apriori(records, min_support=0.0022, min_confidence=0.20, min_lift=3, min_length = 4)

# %%
# Store rules in result variable
results = list(rules)# See the items that were bought together with their support
results_list = []
for i in range(0, len(results)):
    results_list.append('RULE:\t' + str(results[i][0]) + '\nSUPPORT:\t' + str(results[i][1]))

# %%
print(len(results_list))
# Out:
# 1072

# %%
for i in range(len(results_list)):
  print(results_list[i])
# Out:
# RULE:	frozenset({'Instant food products', 'hamburger meat'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'root vegetables', 'beef'})
# SUPPORT:	0.017386883579054397
# RULE:	frozenset({'berries', 'whipped/sour cream'})
# SUPPORT:	0.009049313675648195
# RULE:	frozenset({'bottled beer', 'liquor'})
# SUPPORT:	0.004677173360447382
# RULE:	frozenset({'bottled beer', 'red/blush wine'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'coffee', 'condensed milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'flour', 'margarine'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'flour', 'sugar'})
# SUPPORT:	0.00498220640569395
# RULE:	frozenset({'flour', 'whipped/sour cream'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'mustard', 'frankfurter'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'herbs'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'popcorn', 'salty snack'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'white bread', 'processed cheese'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'root vegetables', 'rice'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'sausage', 'sliced cheese'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'tropical fruit', 'turkey'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'Instant food products', 'hamburger meat'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'bottled water', 'UHT-milk', 'soda'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'root vegetables', 'other vegetables', 'baking powder'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'other vegetables', 'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'whole milk', 'other vegetables', 'baking powder'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'whole milk', 'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'bottled water', 'root vegetables', 'beef'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'butter', 'beef'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'yogurt', 'butter', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'beef'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'root vegetables', 'domestic eggs', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'fruit/vegetable juice', 'root vegetables', 'beef'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.01728520589730554
# RULE:	frozenset({'root vegetables', 'newspapers', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pork', 'other vegetables', 'beef'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'root vegetables', 'other vegetables', 'beef'})
# SUPPORT:	0.007930859176410779
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'beef'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'root vegetables', 'pip fruit', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'pork', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'beef'})
# SUPPORT:	0.00498220640569395
# RULE:	frozenset({'root vegetables', 'sausage', 'beef'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'soda', 'beef'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'beef'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'whole milk', 'beef'})
# SUPPORT:	0.008032536858159633
# RULE:	frozenset({'yogurt', 'root vegetables', 'beef'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'yogurt', 'whipped/sour cream', 'beef'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'berries', 'whole milk', 'butter'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'berries', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.009049313675648195
# RULE:	frozenset({'berries', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'berries', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0
 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'root vegetables', 'domestic eggs', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'domestic eggs', 'whole milk', 'sugar'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'yogurt', 'domestic eggs', 'whipped/sour cream'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'flour', 'nan', 'margarine'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'flour', 'nan', 'sugar'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'flour', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'flour', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'flour', 'yogurt', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'flour', 'root vegetables', 'whole milk'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'flour', 'whole milk', 'sugar'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'flour', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'mustard', 'frankfurter'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'frankfurter'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'pip fruit', 'frankfurter'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'frankfurter', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'frozen fish', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'frozen fish', 'whole milk', 'yogurt'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'root vegetables', 'frozen meals'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'whole milk', 'tropical fruit', 'frozen meals'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'fruit/vegetable juice', 'root vegetables', 'frozen vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'fruit/vegetable juice', 'frozen vegetables', 'soda'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'frozen vegetables'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'other vegetables', 'frozen vegetables'})
# SUPPORT:	0.006100660904931368
# RULE:	frozenset({'other vegetables', 'frozen vegetables', 'whipped/sour cream'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'frozen vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'frozen vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'tropical fruit', 'frozen vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'frozen vegetables', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'fruit/vegetable juice', 'other vegetables', 'long life bakery product'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'fruit/vegetable juice', 'whole milk', 'long life bakery product'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'napkins', 'fruit/vegetable juice', 'root vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'fruit/vegetable juice', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'fruit/vegetable juice', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'fruit/vegetable juice', 'soda', 'salty snack'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'fruit/vegetable juice', 'whole milk', 'salty snack'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'salty snack'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'white bread', 'fruit/vegetable juice', 'soda'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'white bread', 'fruit/vegetable juice', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'whipped/sour cream'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'white bread', 'fruit/vegetable juice', 'yogurt'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'grapes', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'grapes', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'yogurt', 'grapes', 'other vegetables'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'grapes', 'tropical fruit', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'pip fruit', 'ham', 'other vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'tropical fruit', 'ham'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'ham', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'white bread', 'ham', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'pip fruit', 'other vegetables', 'hamburger meat'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'other vegetables', 'hamburger meat'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'hard cheese', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'hard cheese', 'other vegetables', 'sausage'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'hard cheese', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'hard cheese', 'root vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'hard cheese', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'herbs'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'root vegetables', 'herbs', 'other vegetables'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'whole milk', 'herbs', 'other vegetables'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'whole milk', 'herbs', 'rolls/buns'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'herbs', 'whole milk'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'tropical fruit', 'herbs', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'hygiene articles', 'napkins', 'whole milk'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'hygiene articles', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'hygiene articles', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'hygiene articles', 'pip fruit', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'hygiene articles', 'tropical fruit', 'whole milk'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'hygiene articles', 'tropical fruit', 'yogurt'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'long life bakery product', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'long life bakery product', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'long life bakery product', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'margarine', 'root vegetables', 'pip fruit'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'margarine', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'margarine', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'margarine', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'margarine', 'yogurt', 'whipped/sour cream'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'popcorn', 'nan', 'salty snack'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'processed cheese', 'white bread'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'nan', 'root vegetables', 'rice'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'nan', 'sausage', 'sliced cheese'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'nan', 'tropical fruit', 'turkey'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'napkins', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'napkins', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'napkins', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'napkins', 'tropical fruit', 'shopping bags'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'oil', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'yogurt', 'oil', 'other vegetables'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'oil', 'root vegetables', 'whole milk'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'onions', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.0056939501779359435
# RULE:	frozenset({'onions', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'onions', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'onions', 'root vegetables', 'rolls/buns'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'onions', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'onions', 'root vegetables', 'whole milk'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'onions', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pip fruit', 'other vegetables', 'pork'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'other vegetables'})
# SUPPORT:	0.00945602440264362
# RULE:	frozenset({'pip fruit', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.005592272496187087
# RULE:	frozenset({'other vegetables', 'sugar', 'pork'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'other vegetables', 'rice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'whole milk', 'other vegetables', 'rice'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'whole milk', 'roll products', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'other vegetables', 'sliced cheese'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'root vegetables', 'other vegetables', 'soft cheese'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.012302999491611592
# RULE:	frozenset({'other vegetables', 'whipped/sour cream', 'salty snack'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'semi-finished bread', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'semi-finished bread', 'yogurt', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'sliced cheese'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'other vegetables', 'soft cheese', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'specialty cheese', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'whipped/sour cream', 'sugar'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.007829181494661922
# RULE:	frozenset({'waffles', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'white bread', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'yogurt', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.010167768174885612
# RULE:	frozenset({'root vegetables', 'pasta', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'pastry', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'rolls/buns'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.0052872394509405184
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whipped/sour cream'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'shopping bags'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'whipped/sour cream'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'white bread', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'tropical fruit', 'pip fruit'})
# SUPPORT:	0.006405693950177936
# RULE:	frozenset({'white bread', 'pip fruit', 'yogurt'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'whole milk', 'rice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'sausage', 'rolls/buns', 'shopping bags'})
# SUPPORT:	0.005998983223182512
# RULE:	frozenset({'sausage', 'rolls/buns', 'sliced cheese'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'yogurt', 'root vegetables', 'tropical fruit'})
# SUPPORT:	0.00813421453990849
# RULE:	frozenset({'yogurt', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.006405693950177936
# RULE:	frozenset({'whole milk', 'whipped/sour cream', 'salty snack'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'sausage', 'whole milk', 'sliced cheese'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'yogurt', 'sausage', 'sliced cheese'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'tropical fruit', 'sliced cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whole milk', 'whipped/sour cream', 'sliced cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'whole milk', 'sliced cheese'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'yogurt', 'whole milk', 'soft cheese'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'yogurt', 'tropical fruit', 'waffles'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.0062023385866802234
# RULE:	frozenset({'whole milk', 'waffles', 'whipped/sour cream'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'bottled water', 'nan', 'UHT-milk', 'soda'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'root vegetables', 'other vegetables', 'baking powder'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'other vegetables', 'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'nan', 'whole milk', 'other vegetables', 'baking powder'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'nan', 'whole milk', 'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'bottled water', 'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'nan', 'root vegetables', 'butter', 'beef'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'yogurt', 'butter', 'beef'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'citrus fruit', 'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'whole milk', 'beef'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'root vegetables', 'domestic eggs', 'beef'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'whole milk', 'domestic eggs', 'other vegetables', 'beef'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'fruit/vegetable juice', 'root vegetables', 'beef'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'root vegetables', 'newspapers', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'pork', 'other vegetables', 'beef'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'nan', 'root vegetables', 'other vegetables', 'beef'})
# SUPPORT:	0.007829181494661922
# RULE:	frozenset({'nan', 'tropical fruit', 'other vegetables', 'beef'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'nan', 'root vegetables', 'pip fruit', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'nan', 'root vegetables', 'pork', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'root vegetables', 'rolls/buns', 'beef'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'nan', 'root vegetables', 'sausage', 'beef'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'root vegetables', 'soda', 'beef'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'nan', 'root vegetables', 'tropical fruit', 'beef'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'nan', 'root vegetables', 'whipped/sour cream', 'beef'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'whole milk', 'beef'})
# SUPPORT:	0.007930859176410779
# RULE:	frozenset({'nan', 'root vegetables', 'yogurt', 'beef'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'whole milk', 'pork', 'other vegetables', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'beef'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'whole milk', 'rolls/buns', 'other vegetables', 'beef'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'other vegetables', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whole milk', 'root vegetables', 'other vegetables', 'beef'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'yogurt', 'root vegetables', 'other vegetables', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'beef'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'yogurt', 'whole milk', 'other vegetables', 'beef'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'whole milk', 'root vegetables', 'rolls/buns', 'beef'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'whole milk', 'beef'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'beef'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'berries', 'nan', 'whole milk', 'butter'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'berries', 'nan', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'berries', 'nan', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.004270462633451958
# RULE:	frozenset({'berries', 'nan', 'yogurt', 'whipped/sour cream'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'bottled water', 'citrus fruit', 'bottled beer', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'bottled water', 'nan', 'fruit/vegetable juice', 'bottled beer'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'bottled beer', 'other vegetables', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'whole milk', 'bottled beer', 'other vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'bottled water', 'nan', 'root vegetables', 'butter'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'bottled water', 'other vegetables', 'whole milk', 'butter'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'bottled water', 'root vegetables', 'butter', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'bottled water', 'citrus fruit', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'bottled water', 'citrus fruit', 'tropical fruit', 'whole milk'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'bottled water', 'curd', 'yogurt', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'bottled water', 'nan', 'tropical fruit', 'frozen vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'bottled water', 'yogurt', 'fruit/vegetable juice', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({
 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'frankfurter', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'whole milk', 'other vegetables', 'frankfurter', 'nan'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'rolls/buns', 'whole milk', 'frankfurter', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'frankfurter', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'fruit/vegetable juice', 'whole milk', 'other vegetables', 'nan', 'frozen vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'whole milk', 'other vegetables', 'nan', 'frozen vegetables'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'nan', 'frozen vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'whole milk', 'other vegetables', 'whipped/sour cream', 'nan', 'frozen vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'other vegetables', 'whipped/sour cream', 'nan', 'frozen vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'whole milk', 'other vegetables', 'nan', 'frozen vegetables'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'root vegetables', 'whole milk', 'tropical fruit', 'nan', 'frozen vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'fruit/vegetable juice', 'pip fruit', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'pip fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'fruit/vegetable juice', 'root vegetables', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'fruit/vegetable juice', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'root vegetables', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'fruit/vegetable juice', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'fruit/vegetable juice', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'root vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'whole milk', 'soda', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'herbs', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'whole milk', 'other vegetables', 'nan', 'long life bakery product'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'margarine', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'napkins', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'whole milk', 'other vegetables', 'nan', 'newspapers'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'nan', 'newspapers'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'oil', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'oil', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'onions', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'yogurt', 'onions', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'pastry', 'pip fruit', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'pastry', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'yogurt', 'pastry', 'root vegetables', 'other vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'pastry', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'pastry', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'pip fruit', 'whole milk', 'pork', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'pip fruit', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.005490594814438231
# RULE:	frozenset({'yogurt', 'root vegetables', 'pip fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'pip fruit', 'tropical fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pip fruit', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'yogurt', 'pip fruit', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'pip fruit', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'yogurt', 'pip fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'pip fruit', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'rolls/buns', 'whole milk', 'pork', 'other vegetables', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'root vegetables', 'whole milk', 'pork', 'other vegetables', 'nan'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'whole milk', 'pork', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'whole milk', 'pork', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'rolls/buns', 'root vegetables', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'rolls/buns', 'root vegetables', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'rolls/buns', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.006100660904931368
# RULE:	frozenset({'yogurt', 'rolls/buns', 'root vegetables', 'other vegetables', 'nan'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'yogurt', 'rolls/buns', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'rolls/buns', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'root vegetables', 'sausage', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'whole milk', 'shopping bags', 'other vegetables', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'whole milk', 'sliced cheese', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'soda', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'whole milk', 'soda', 'other vegetables', 'nan'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'root vegetables', 'tropical fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'root vegetables', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.006914082358922217
# RULE:	frozenset({'yogurt', 'root vegetables', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'root vegetables', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'yogurt', 'root vegetables', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'whole milk', 'white bread', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.007727503812913066
# RULE:	frozenset({'yogurt', 'sausage', 'soda', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'sausage', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'whole milk', 'soda', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'whole milk', 'tropical fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'yogurt', 'tropical fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0075241484494153535
# RULE:	frozenset({'yogurt', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.005490594814438231
# RULE:	frozenset({'pastry', 'rolls/buns', 'root vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'pastry', 'root vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'yogurt', 'pastry', 'sausage', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'pastry', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'yogurt', 'root vegetables', 'pip fruit', 'tropical fruit', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'root vegetables', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'yogurt', 'sausage', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'pip fruit', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'yogurt', 'pip fruit', 'whole milk', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'rolls/buns', 'root vegetables', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'yogurt', 'rolls/buns', 'root vegetables', 'tropical fruit', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'rolls/buns', 'root vegetables', 'whole milk', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'rolls/buns', 'sausage', 'shopping bags', 'soda', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'rolls/buns', 'soda', 'tropical fruit', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'rolls/buns', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'yogurt', 'rolls/buns', 'whole milk', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'sausage', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'root vegetables', 'sausage', 'whole milk', 'nan'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'whole milk', 'tropical fruit', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'root vegetables', 'tropical fruit', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.005592272496187087
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'yogurt', 'sausage', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.004270462633451958
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'root vegetables', 'pip fruit', 'whole milk', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'pip fruit', 'whole milk', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'rolls/buns', 'root vegetables', 'whole milk', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'rolls/buns', 'whole milk', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'other vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'rolls/buns', 'root vegetables', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'other vegetables', 'butter', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'citrus fruit', 'yogurt', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'citrus fruit', 'yogurt', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'root vegetables', 'pip fruit', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'pip fruit', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'rolls/buns', 'root vegetables', 'whole milk', 'other vegetables', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'rolls/buns', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'tropical fruit', 'other vegetables', 'nan'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'yogurt', 'root vegetables', 'whole milk', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'whole milk', 'tropical fruit', 'other vegetables', 'whipped/sour cream', 'nan'})
# SUPPORT:	0.002338586680223691

# %% [markdown]
# RULE 1: \t fro
# zenset({'Instant food products', 'hamburger meat'})\nSUPPORT:\t0.003050330452465684
#
# If a customer buys "Instant food products" and "hamburger meat", then there is a support of 0.00305, which means that these items are purchased together in approximately 0.305% of all transactions.

# %% [markdown]
# # 21l-5654

# %%
#importing data.csv
columns = ["age","workClass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","income"]
data = pd.read_csv("DATA.csv",names=columns)
data.head()
# Out:
#    age          workClass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data = data.head(500)

# %%
print(data.columns)
data.shape
# Out:
# Index(['age', 'workClass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')
# (500, 15)

# %%
data.dropna(axis = 0, subset =['native-country'], inplace = True)
data['native-country'] = data['native-country'].astype('str')
data = data[~data['native-country'].str.contains("\?")]

missing_values =data.isna().sum()
print("Missing values: \n",missing_values)
# Out:
# Missing values:
#  age               0
# workClass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
data.shape
# Out:
# (500, 15)

# %%
data.head()
# Out:
#    age          workClass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data_rows = []
for i in range(0, 500):
    data_rows.append([str(data.values[i,u]) for u in range(0, 15)])

# %%
# 30dayssupportemf

# %% [markdown]
# # Use confidence as interestingness measure of an association rule. Rank the top 10 association
# rules for at-least the three different combinations of support and confidence. Explain the rules and
# why you consider it interesting and useful. Furthermore, also give recommendations based on the
# discovered rules that might help the user.

# %%
rule = apriori(data_rows, min_support=0.3, min_confidence=0.6)
sorted_rules = sorted(rule, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]
for rule1 in sorted_rules:
    lhs = ', '.join(rule1.ordered_statistics[0].items_base)
    rhs = ', '.join(rule1.ordered_statistics[0].items_add)
    confidence = rule1.ordered_statistics[0].confidence
    support = rule1.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  Female -> 0
# Confidence: 1.0
# Support: 0.334
# Rule:  HS-grad -> 0
# Confidence: 1.0
# Support: 0.314
# Rule:  HS-grad -> 9
# Confidence: 1.0
# Support: 0.314
# Rule:  Husband ->  Male
# Confidence: 1.0
# Support: 0.378
# Rule:  Husband ->  Married-civ-spouse
# Confidence: 1.0
# Support: 0.378
# Rule:  Husband -> 0
# Confidence: 1.0
# Support: 0.378
# Rule:  Married-civ-spouse -> 0
# Confidence: 1.0
# Support: 0.452
# Rule:  Never-married -> 0
# Confidence: 1.0
# Support: 0.34
# Rule: 40 -> 0
# Confidence: 1.0
# Support: 0.53

# %% [markdown]
# These rules are generateed on min_support 0.3 and confidence of 0.6 , therefore the output has all relations that achieve these rules. Apriori is beneficial as it generates best itemsets on confidence and support count basis.
#
# Usefull:
# Rule: -> 0
# Description: This rule indicates that all instances in the dataset have the target variable set to 0, with a confidence of 1.0 and support of 1.0. This rule suggests a strong association with the majority class.
# Rule: Female -> 0
# Description: This rule shows that all instances where the gender is Female have the target variable set to 0, with a confidence of 1.0 and support of 0.334. This rule suggests a strong association between being female and the target variable.
# Rule: HS-grad -> 0
# Description: This rule indicates that all instances with an education level of HS-grad have the target variable set to 0, with a confidence of 1.0 and support of 0.314. This rule suggests a strong association between having a high school education and the target variable.
# Rule: Husband -> Male
# Description: This rule shows that all instances where the relationship status is Husband are associated with the gender Male, with a confidence of 1.0 and support of 0.378. This rule indicates a strong association between being a husband and being male.
# Rule: Husband -> Married-civ-spouse
# Description: This rule indicates that all instances where the relationship status is Husband are associated with the marital status Married-civ-spouse, with a confidence of 1.0 and support of 0.378. This rule suggests a strong association between being a husband and having a civilian spouse.
# Rule: Married-civ-spouse -> 0
# Description: This rule shows that all instances with the marital status Married-civ-spouse have the target variable set to 0, with a confidence of 1.0 and support of 0.452. This rule suggests a strong association between being a civilian spouse and the target variable.
# Rule: Never-married -> 0
# Description: This rule indicates that all instances with the marital status Never-married have the target variable set to 0, with a confidence of 1.0 and support of 0.34. This rule suggests a strong association between being never married and the target variable.
# Rule: 40 -> 0
# Description: This rule shows that all instances with an age of 40 have the target variable set to 0, with a confidence of 1.0 and support of 0.53. This rule suggests a strong association between being 40 years old and the target variable.

# %%
rule2 = apriori(data_rows, min_support=0.5, min_confidence=0.5)
sorted_rules = sorted(rule2, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]

for rule2 in sorted_rules:
    lhs = ', '.join(rule2.ordered_statistics[0].items_base)
    rhs = ', '.join(rule2.ordered_statistics[0].items_add)
    confidence = rule2.ordered_statistics[0].confidence
    support = rule2.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  ->  United-States
# Confidence: 0.906
# Support: 0.906
# Rule:  -> 0,  United-States
# Confidence: 0.906
# Support: 0.906
# Rule:  ->  White
# Confidence: 0.836
# Support: 0.836
# Rule:  ->  White, 0
# Confidence: 0.836
# Support: 0.836
# Rule:  ->  <=50K
# Confidence: 0.782
# Support: 0.782
# Rule:  ->  <=50K, 0
# Confidence: 0.782
# Support: 0.782
# Rule:  ->  White,  United-States
# Confidence: 0.772
# Support: 0.772
# Rule:  ->  White, 0,  United-States
# Confidence: 0.772
# Support: 0.772
# Rule:  ->  <=50K,  United-States
# Confidence: 0.708
# Support: 0.708

# %% [markdown]
# Rule: -> 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K or >50K) and the 0 value, which is the majority class in the dataset. This rule has a confidence of 1.0 and support of 1.0, meaning that all instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> United-States
# Explanation: This rule shows that there is a strong association between the country of origin (United-States) and the target variable. The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> 0, United-States
# Explanation: This rule indicates that there is a strong association between the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White
# Explanation: This rule shows that there is a strong association between the race (White) and the target variable. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, 0
# Explanation: This rule indicates that there is a strong association between the race (White) and the 0 value, the majority class. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and itself. This rule has a confidence of 0.782 and support of 0.782, meaning that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K, 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K) and the 0 value, the majority class. The confidence of 0.782 indicates that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, United-States
# Explanation: This rule shows that there is a strong association between the race (White) and the country of origin (United-States) and the target variable. The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, 0, United-States
# Explanation: This rule indicates that there is a strong association between the race (White), the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K, United-States
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and the country of origin (United-States) and the target variable. The confidence of 0.708 indicates that 70.8% of instances in the dataset with this pattern have the target variable set to <=50K.

# %%
rules = apriori(data_rows, min_support=0.5, min_confidence=0.2)
sorted_rules = sorted(rules, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]
iter+=0.2
for rule in sorted_rules:
    lhs = ', '.join(rule.ordered_statistics[0].items_base)
    rhs = ', '.join(rule.ordered_statistics[0].items_add)
    confidence = rule.ordered_statistics[0].confidence
    support = rule.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  ->  United-States
# Confidence: 0.906
# Support: 0.906
# Rule:  -> 0,  United-States
# Confidence: 0.906
# Support: 0.906
# Rule:  ->  White
# Confidence: 0.836
# Support: 0.836
# Rule:  ->  White, 0
# Confidence: 0.836
# Support: 0.836
# Rule:  ->  <=50K
# Confidence: 0.782
# Support: 0.782
# Rule:  ->  <=50K, 0
# Confidence: 0.782
# Support: 0.782
# Rule:  ->  White,  United-States
# Confidence: 0.772
# Support: 0.772
# Rule:  ->  White, 0,  United-States
# Confidence: 0.772
# Support: 0.772
# Rule:  ->  <=50K,  United-States
# Confidence: 0.708
# Support: 0.708

# %% [markdown]
# # Use interest as an interestingness measure of an association rule. Rank the top 10 association
# rules for at least three combinations of support and interest. Explain the rules and why you
# consider it interesting and useful. Furthermore, also give recommendations based on the
# discovered rules that might help the user.

# %%
rules = apriori(data_rows, min_support=0.5, min_confidence=0.2)
sorted_rules = sorted(rules, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]
iter+=0.2
for rule in sorted_rules:
    lhs = ', '.join(rule.ordered_statistics[0].items_base)
    rhs = ', '.join(rule.ordered_statistics[0].items_add)
    confidence = rule.ordered_statistics[0].confidence
    support = rule.support
    lhs = rule.ordered_statistics[0].items_base
    rhs = rule.ordered_statistics[0].items_add
    support_lhs = data[lhs].sum() / 500
    support_rhs = data[rhs].sum() / 500
    interest = support_lhs * (confidence - support_rhs)
    rule.interest = interest
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-37f730e9d8a1> in <cell line: 4>()
#       9     lhs = rule.ordered_statistics[0].items_base
#      10     rhs = rule.ordered_statistics[0].items_add
# ---> 11     interest = rule.interest
#      12     # support_lhs = data[lhs].sum() / 500
#      13     # support_rhs = data[rhs].sum() / 500
#
# AttributeError: 'RelationRecord' object has no attribute 'interest'

# %% [markdown]
# #Insights:
#
# Rule: -> 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K or >50K) and the 0 value, which is the majority class in the dataset. This rule has a confidence of 1.0 and support of 1.0, meaning that all instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> United-States
# Explanation: This rule shows that there is a strong association between the country of origin (United-States) and the target variable. The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> 0, United-States
# Explanation: This rule indicates that there is a strong association between the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White
# Explanation: This rule shows that there is a strong association between the race (White) and the target variable. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, 0
# Explanation: This rule indicates that there is a strong association between the race (White) and the 0 value, the majority class. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and itself. This rule has a confidence of 0.782 and support of 0.782, meaning that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K, 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K) and the 0 value, the majority class. The confidence of 0.782 indicates that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, United-States
# Explanation: This rule shows that there is a strong association between the race (White) and the country of origin (United-States) and the target variable. The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> White, 0, United-States
# Explanation: This rule indicates that there is a strong association between the race (White), the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# Rule:  -> <=50K, United-States
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and the country of origin (United-States) and the target variable. The confidence of 0.708 indicates that 70.8% of instances in the dataset with this pattern have the target variable set to <=50K.

# %% [markdown]
# # Questions:
# Age and Hours Worked Association:
# Rule: {age>40} -> {hours-per-week>40}
# Explanation: This rule could suggest that individuals above the age of 40 tend to work more than 40 hours per week.
# Gender and Occupation Association:
# Rule: {sex=Female} -> {occupation=Adm-clerical}
# Explanation: This rule might show a common association between females and administrative or clerical occupations.
# Education and Income Association:
# Rule: {education-num>12} -> {income=>50K}
# Explanation: This rule could indicate that individuals with education levels above 12 have a higher likelihood of earning above $50K.
