# %%
import pandas as pd

# %%
filename ='FSC_Time_Table__List_of_Courses_Fall_2023_v1.1_BtCb3Zv (1).xlsx'

# %%
time_table = pd.read_excel(filename)

# %%
time_table.head()
# Out:
#   FAST School of Computing TIME TABLE Fall 2023 <v1.1>    Unnamed: 1  \
# 0                                        Color Codes             NaN
# 1                                            Periods             NaN
# 2                                               Days            Room
# 3              Monday                 Monday            Seminar Hall
# 4                                                NaN            CS-2
#
#   Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0        NaN         NaN         NaN   BDS-2022
# 1         10        20.0        30.0        NaN
# 2  8:00 a.m.         NaN         NaN        NaN
# 3        NaN         NaN         NaN        NaN
# 4        NaN         NaN         NaN        NaN
#
#                           Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  \
# 0                           BDS-2023         NaN         NaN   BDS-2022  ...
# 1                                 40        50.0        60.0         10  ...
# ...
