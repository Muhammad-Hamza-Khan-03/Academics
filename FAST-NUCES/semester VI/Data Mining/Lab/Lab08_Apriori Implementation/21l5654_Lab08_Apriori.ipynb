# %% [markdown]
# > ## Installing packages for apriori algorithm (apyori)

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in d:\python64\lib\site-packages (1.1.2)

# %% [markdown]
# > ## Finding frequent itemsets in groceries data

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
df = pd.read_csv('groceries_dataset.csv')

# %%
df.shape
# Out:
# (9835, 32)

# %%
records = []
for i in range(0, 9835):
    records.append([str(df.values[i,u]) for u in range(0, 32)]) #records of all rows computation

# %%
rules = apriori(records, min_support=0.0022, min_confidence=0.20, min_lift=3, min_length = 4)

# %%
# Store rules in result variable
results = list(rules)# See the items that were bought together with their support
results_list = []
for i in range(0, len(results)):
    results_list.append('RULE:\t' + str(results[i][0]) + '\nSUPPORT:\t' + str(results[i][1]))

# %%
print(len(results_list)) #total results
# Out:
# 1072

# %%
for i in range(len(results_list)):
  print(results_list[i])
# Out:
# RULE:	frozenset({'hamburger meat', 'Instant food products'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'baking powder', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'root vegetables', 'beef'})
# SUPPORT:	0.017386883579054397
# RULE:	frozenset({'berries', 'whipped/sour cream'})
# SUPPORT:	0.009049313675648195
# RULE:	frozenset({'liquor', 'bottled beer'})
# SUPPORT:	0.004677173360447382
# RULE:	frozenset({'red/blush wine', 'bottled beer'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'coffee', 'condensed milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'flour', 'margarine'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'flour', 'sugar'})
# SUPPORT:	0.00498220640569395
# RULE:	frozenset({'whipped/sour cream', 'flour'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'frankfurter', 'mustard'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'herbs'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'salty snack', 'popcorn'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'white bread', 'processed cheese'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'root vegetables', 'rice'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'sliced cheese', 'sausage'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'tropical fruit', 'turkey'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'hamburger meat', 'Instant food products'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'UHT-milk', 'soda', 'bottled water'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'baking powder', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'baking powder', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'baking powder', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'baking powder', 'other vegetables', 'whole milk'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'baking powder', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'beef', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'root vegetables', 'beef'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'yogurt', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'beef'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'beef', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.01728520589730554
# RULE:	frozenset({'root vegetables', 'newspapers', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pork', 'beef', 'other vegetables'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'root vegetables', 'beef', 'other vegetables'})
# SUPPORT:	0.007930859176410779
# RULE:	frozenset({'tropical fruit', 'beef', 'other vegetables'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'pip fruit', 'root vegetables', 'beef'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'pork', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'beef', 'rolls/buns'})
# SUPPORT:	0.00498220640569395
# RULE:	frozenset({'root vegetables', 'beef', 'sausage'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'beef', 'soda'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'beef'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'beef', 'whole milk'})
# SUPPORT:	0.008032536858159633
# RULE:	frozenset({'root vegetables', 'yogurt', 'beef'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'beef'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'berries', 'butter', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'berries', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.009049313675648195
# RULE:	frozenset({'berries', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'berries', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.004270462633451958
# RULE:	frozenset({'berries', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'bottled beer', 'citrus fruit', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'bottled beer', 'fruit/vegetable juice', 'bottled water'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'liquor', 'nan', 'bottled beer'})
# SUPPORT:	0.004677173360447382
# RULE:	frozenset({'red/blush wine', 'nan', 'bottled beer'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'butter', 'root vegetables', 'bottled water'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'yogurt', 'curd', 'bottled water'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'frozen vegetables', 'bottled water'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'onions', 'root vegetables', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'pork', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'brown bread', 'citrus fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'brown bread', 'curd', 'yogurt'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'brown bread', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'brown bread', 'fruit/vegetable juice'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'whipped/sour cream', 'brown bread', 'other vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'brown bread'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'chocolate', 'whole milk'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'whipped/sour cream', 'citrus fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'yogurt', 'curd'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'other vegetables', 'domestic eggs'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'butter', 'root vegetables', 'domestic eggs'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'butter', 'tropical fruit', 'domestic eggs'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'whole milk', 'domestic eggs'})
# SUPPORT:	0.005998983223182512
# RULE:	frozenset({'butter', 'yogurt', 'domestic eggs'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'tropical fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'butter', 'yogurt', 'fruit/vegetable juice'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'butter', 'hamburger meat', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'hygiene articles', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'hygiene articles', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'onions', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.0066090493136756485
# RULE:	frozenset({'butter', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.005795627859684799
# RULE:	frozenset({'butter', 'root vegetables', 'tropical fruit'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'butter', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'butter', 'whipped/sour cream', 'sausage'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'butter', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'tropical fruit', 'yogurt'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'butter', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.006710726995424504
# RULE:	frozenset({'butter', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'butter milk', 'other vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter milk', 'pip fruit', 'other vegetables'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'butter milk', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter milk', 'pip fruit', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter milk', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'tropical fruit', 'yogurt', 'candy'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'canned beer', 'shopping bags', 'sausage'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'other vegetables', 'cat food'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'yogurt', 'other vegetables', 'cat food'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'chicken'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'yogurt', 'citrus fruit', 'chicken'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'chicken'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'domestic eggs', 'whole milk', 'chicken'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'hamburger meat', 'other vegetables', 'chicken'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'pip fruit', 'other vegetables', 'chicken'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'other vegetables', 'chicken', 'sausage'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'chicken'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'yogurt', 'other vegetables', 'chicken'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'root vegetables', 'chicken', 'sausage'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'chicken'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.005998983223182512
# RULE:	frozenset({'root vegetables', 'yogurt', 'chicken'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'whipped/sour cream', 'whole milk', 'chicken'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'chicken'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'chocolate', 'other vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'chocolate', 'yogurt', 'fruit/vegetable juice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'chocolate', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'chocolate', 'long life bakery product', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'chocolate', 'tropical fruit', 'pastry'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'citrus fruit', 'curd'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'citrus fruit', 'curd'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'frozen vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'citrus fruit', 'fruit/vegetable juice', 'soda'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'tropical fruit', 'citrus fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'tropical fruit', 'napkins', 'citrus fruit'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'oil', 'citrus fruit', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'onions', 'citrus fruit', 'other vegetables'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'other vegetables'})
# SUPPORT:	0.010371123538383325
# RULE:	frozenset({'tropical fruit', 'citrus fruit', 'other vegetables'})
# SUPPORT:	0.009049313675648195
# RULE:	frozenset({'pip fruit', 'root vegetables', 'citrus fruit'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'pip fruit', 'shopping bags', 'citrus fruit'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'citrus fruit'})
# SUPPORT:	0.005592272496187087
# RULE:	frozenset({'root vegetables', 'pork', 'citrus fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'citrus fruit'})
# SUPPORT:	0.0056939501779359435
# RULE:	frozenset({'whipped/sour cream', 'citrus fruit', 'sausage'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'citrus fruit'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'nan', 'coffee', 'condensed milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'coffee', 'soda', 'fruit/vegetable juice'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'coffee'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'tropical fruit', 'coffee', 'yogurt'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'curd', 'other vegetables', 'cream cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'curd', 'cream cheese'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'domestic eggs', 'other vegetables', 'cream cheese'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'domestic eggs', 'whole milk', 'cream cheese'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'cream cheese'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'other vegetables', 'cream cheese'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'cream cheese'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'pip fruit', 'whole milk', 'cream cheese'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'yogurt', 'cream cheese'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'whipped/sour cream', 'whole milk', 'cream cheese'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'cream cheese'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'dessert', 'curd', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'domestic eggs', 'curd', 'other vegetables'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'curd'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'domestic eggs', 'tropical fruit', 'curd'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'domestic eggs', 'yogurt', 'curd'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'hamburger meat', 'curd', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'yogurt', 'margarine', 'curd'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whipped/sour cream', 'curd', 'other vegetables'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'yogurt', 'curd', 'pastry'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'curd'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pip fruit', 'whipped/sour cream', 'curd'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'pip fruit', 'yogurt', 'curd'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'whipped/sour cream', 'curd', 'rolls/buns'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'curd'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'yogurt', 'curd'})
# SUPPORT:	0.004677173360447382
# RULE:	frozenset({'yogurt', 'curd', 'sausage'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'tropical fruit', 'whipped/sour cream', 'curd'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'tropical fruit', 'yogurt', 'curd'})
# SUPPORT:	0.0052872394509405184
# RULE:	frozenset({'whipped/sour cream', 'curd', 'whole milk'})
# SUPPORT:	0.005897305541433655
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'curd'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'dessert', 'fruit/vegetable juice', 'other vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'yogurt', 'dessert', 'fruit/vegetable juice'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'pip fruit', 'dessert', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'dessert', 'other vegetables'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'whipped/sour cream', 'dessert', 'other vegetables'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'root vegetables', 'yogurt', 'dessert'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'domestic eggs', 'hygiene articles', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'domestic eggs', 'margarine', 'other vegetables'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'margarine'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'domestic eggs', 'tropical fruit', 'margarine'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'domestic eggs', 'margarine', 'whole milk'})
# SUPPORT:	0.005185561769191663
# RULE:	frozenset({'domestic eggs', 'onions', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.007320793085917641
# RULE:	frozenset({'domestic eggs', 'other vegetables', 'sugar'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'domestic eggs', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'domestic eggs', 'whole milk', 'sugar'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'domestic eggs', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'nan', 'flour', 'margarine'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'nan', 'flour', 'sugar'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'whipped/sour cream', 'nan', 'flour'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'flour', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'flour', 'other vegetables', 'yogurt'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'flour', 'whole milk'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'flour', 'whole milk', 'sugar'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'whipped/sour cream', 'flour', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'frankfurter', 'mustard'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'frankfurter'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'pip fruit', 'yogurt', 'frankfurter'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'whipped/sour cream', 'frankfurter'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'whole milk', 'frozen fish'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'whole milk', 'frozen fish'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'frozen meals', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'frozen meals', 'whole milk'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'root vegetables', 'fruit/vegetable juice', 'frozen vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'soda', 'fruit/vegetable juice', 'frozen vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'fruit/vegetable juice', 'frozen vegetables'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'other vegetables', 'frozen vegetables'})
# SUPPORT:	0.006100660904931368
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'frozen vegetables'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'frozen vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'frozen vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'tropical fruit', 'whipped/sour cream', 'frozen vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'frozen vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'long life bakery product', 'fruit/vegetable juice', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'long life bakery product', 'fruit/vegetable juice', 'whole milk'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'napkins', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'fruit/vegetable juice'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'salty snack', 'soda', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'salty snack', 'whole milk', 'fruit/vegetable juice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'salty snack', 'fruit/vegetable juice', 'yogurt'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'white bread', 'soda', 'fruit/vegetable juice'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'tropical fruit', 'white bread', 'fruit/vegetable juice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'fruit/vegetable juice'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'white bread', 'fruit/vegetable juice', 'yogurt'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'grapes', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'tropical fruit', 'grapes', 'other vegetables'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'grapes', 'other vegetables', 'yogurt'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'tropical fruit', 'grapes', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'pip fruit', 'ham', 'other vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'yogurt', 'ham'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'whipped/sour cream', 'ham', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'white bread', 'ham', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'pip fruit', 'hamburger meat', 'other vegetables'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'hamburger meat', 'other vegetables'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'root vegetables', 'other vegetables', 'hard cheese'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'other vegetables', 'hard cheese', 'sausage'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'hard cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'yogurt', 'hard cheese'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'whipped/sour cream', 'whole milk', 'hard cheese'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'herbs'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'root vegetables', 'herbs', 'other vegetables'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'herbs', 'whole milk', 'other vegetables'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'herbs', 'rolls/buns', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'herbs', 'whole milk'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'tropical fruit', 'herbs', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'hygiene articles', 'napkins', 'whole milk'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'hygiene articles', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'tropical fruit', 'hygiene articles', 'pip fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'hygiene articles', 'whole milk', 'pip fruit'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'hygiene articles', 'whole milk'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'tropical fruit', 'hygiene articles', 'yogurt'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'whipped/sour cream', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whipped/sour cream', 'long life bakery product', 'whole milk'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'root vegetables', 'pip fruit', 'margarine'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'margarine'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'margarine'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'yogurt', 'margarine'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'margarine'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'nan', 'salty snack', 'popcorn'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'white bread', 'processed cheese'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'nan', 'root vegetables', 'rice'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'nan', 'sliced cheese', 'sausage'})
# SUPPORT:	0.007015760040671073
# RULE:	frozenset({'tropical fruit', 'nan', 'turkey'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'whipped/sour cream', 'napkins', 'other vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'napkins'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whipped/sour cream', 'root vegetables', 'napkins'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'napkins', 'shopping bags'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'oil', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'oil', 'yogurt', 'other vegetables'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'oil', 'root vegetables', 'whole milk'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'onions', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.0056939501779359435
# RULE:	frozenset({'onions', 'tropical fruit', 'other vegetables'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'onions', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'onions', 'root vegetables', 'rolls/buns'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'onions', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'onions', 'root vegetables', 'whole milk'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'onions', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'pip fruit', 'pork', 'other vegetables'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'other vegetables'})
# SUPPORT:	0.00945602440264362
# RULE:	frozenset({'pip fruit', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.005592272496187087
# RULE:	frozenset({'pork', 'other vegetables', 'sugar'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'other vegetables', 'rice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'whole milk', 'rice'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'roll products', 'other vegetables', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'other vegetables', 'sliced cheese'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'soft cheese', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.012302999491611592
# RULE:	frozenset({'whipped/sour cream', 'salty snack', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'semi-finished bread'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'yogurt', 'other vegetables', 'semi-finished bread'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'sliced cheese'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'soft cheese', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'specialty cheese', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'sugar'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.007829181494661922
# RULE:	frozenset({'waffles', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whipped/sour cream', 'white bread', 'other vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'whipped/sour cream', 'yogurt', 'other vegetables'})
# SUPPORT:	0.010167768174885612
# RULE:	frozenset({'root vegetables', 'pasta', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'pastry'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'rolls/buns'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'root vegetables'})
# SUPPORT:	0.0052872394509405184
# RULE:	frozenset({'pip fruit', 'whipped/sour cream', 'root vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'shopping bags'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'whipped/sour cream'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'white bread'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'tropical fruit', 'pip fruit', 'yogurt'})
# SUPPORT:	0.006405693950177936
# RULE:	frozenset({'pip fruit', 'white bread', 'yogurt'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'whole milk', 'rice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'shopping bags', 'rolls/buns', 'sausage'})
# SUPPORT:	0.005998983223182512
# RULE:	frozenset({'sliced cheese', 'rolls/buns', 'sausage'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'whipped/sour cream'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'yogurt'})
# SUPPORT:	0.00813421453990849
# RULE:	frozenset({'root vegetables', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.006405693950177936
# RULE:	frozenset({'whipped/sour cream', 'salty snack', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'sliced cheese', 'whole milk', 'sausage'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'sliced cheese', 'yogurt', 'sausage'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'tropical fruit', 'yogurt', 'sliced cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'whipped/sour cream', 'whole milk', 'sliced cheese'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'yogurt', 'whole milk', 'sliced cheese'})
# SUPPORT:	0.004575495678698526
# RULE:	frozenset({'soft cheese', 'yogurt', 'whole milk'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'waffles', 'tropical fruit', 'yogurt'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.0062023385866802234
# RULE:	frozenset({'waffles', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'nan', 'UHT-milk', 'soda', 'bottled water'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'baking powder', 'nan', 'root vegetables', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'baking powder', 'nan', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'baking powder', 'nan', 'other vegetables', 'whole milk'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'baking powder', 'nan', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'butter', 'nan', 'yogurt', 'beef'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'beef', 'nan'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'citrus fruit', 'root vegetables', 'beef', 'whole milk'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'domestic eggs', 'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'domestic eggs', 'beef', 'whole milk', 'other vegetables'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'newspapers', 'root vegetables', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'pork', 'beef', 'other vegetables'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'other vegetables'})
# SUPPORT:	0.007829181494661922
# RULE:	frozenset({'tropical fruit', 'nan', 'beef', 'other vegetables'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'pip fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'nan', 'pork', 'beef'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'rolls/buns'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'sausage'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'soda'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'tropical fruit', 'nan', 'root vegetables', 'beef'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'nan', 'whipped/sour cream', 'root vegetables', 'beef'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'beef', 'whole milk'})
# SUPPORT:	0.007930859176410779
# RULE:	frozenset({'nan', 'yogurt', 'root vegetables', 'beef'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'pork', 'beef', 'whole milk', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'beef', 'rolls/buns', 'other vegetables'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'whole milk', 'beef', 'rolls/buns', 'other vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'beef', 'other vegetables'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'beef', 'whole milk', 'other vegetables'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'yogurt', 'beef', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'tropical fruit', 'beef', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'yogurt', 'beef', 'whole milk', 'other vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'beef', 'rolls/buns', 'whole milk'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'beef', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'yogurt', 'beef', 'whole milk'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'berries', 'butter', 'whole milk', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'berries', 'nan', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'berries', 'nan', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.004270462633451958
# RULE:	frozenset({'berries', 'nan', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'nan', 'bottled beer', 'citrus fruit', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'bottled beer', 'fruit/vegetable juice', 'bottled water'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'bottled beer', 'other vegetables', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'yogurt', 'bottled beer', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter', 'nan', 'root vegetables', 'bottled water'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'other vegetables', 'whole milk', 'bottled water'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter', 'root vegetables', 'whole milk', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'citrus fruit', 'whole milk', 'other vegetables', 'bottled water'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'tropical fruit', 'citrus fruit', 'whole milk', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'yogurt', 'curd', 'bottled water'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'tropical fruit', 'nan', 'frozen vegetables', 'bottled water'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'whole milk', 'fruit/vegetable juice', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'onions', 'nan', 'root vegetables', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'nan', 'pork', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'sausage', 'other vegetables', 'rolls/buns', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'other vegetables', 'bottled water'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'bottled water'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'sausage', 'yogurt', 'other vegetables', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'other vegetables', 'whole milk', 'bottled water'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'tropical fruit', 'yogurt', 'other vegetables', 'bottled water'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'yogurt', 'soda', 'rolls/buns', 'bottled water'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'whole milk', 'rolls/buns', 'bottled water'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'tropical fruit', 'yogurt', 'rolls/buns', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'whole milk', 'bottled water'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'tropical fruit', 'root vegetables', 'yogurt', 'bottled water'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'yogurt', 'soda', 'bottled water'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'tropical fruit', 'yogurt', 'whole milk', 'bottled water'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'nan', 'brown bread', 'root vegetables', 'citrus fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'nan', 'brown bread', 'curd', 'yogurt'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'nan', 'brown bread', 'frankfurter', 'yogurt'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'brown bread', 'root vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'nan', 'brown bread', 'fruit/vegetable juice'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'whipped/sour cream', 'nan', 'brown bread', 'other vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'nan', 'brown bread', 'pip fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'brown bread', 'other vegetables', 'whole milk'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'tropical fruit', 'brown bread', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter', 'nan', 'chocolate', 'whole milk'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'citrus fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'citrus fruit', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'nan', 'yogurt', 'curd'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'butter', 'curd', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'yogurt', 'curd', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'nan', 'other vegetables', 'domestic eggs'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'butter', 'nan', 'root vegetables', 'domestic eggs'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'butter', 'nan', 'tropical fruit', 'domestic eggs'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'nan', 'whole milk', 'domestic eggs'})
# SUPPORT:	0.005897305541433655
# RULE:	frozenset({'butter', 'nan', 'yogurt', 'domestic eggs'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'butter', 'other vegetables', 'whole milk', 'domestic eggs'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'root vegetables', 'whole milk', 'domestic eggs'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'yogurt', 'whole milk', 'domestic eggs'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'nan', 'fruit/vegetable juice', 'tropical fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'butter', 'nan', 'yogurt', 'fruit/vegetable juice'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'butter', 'nan', 'hamburger meat', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'hygiene articles', 'other vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'hygiene articles', 'whole milk', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'nan', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'nan', 'onions', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.0056939501779359435
# RULE:	frozenset({'butter', 'nan', 'root vegetables', 'tropical fruit'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'root vegetables'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'sausage'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'tropical fruit'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter', 'nan', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0066090493136756485
# RULE:	frozenset({'butter', 'nan', 'whipped/sour cream', 'yogurt'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'butter', 'other vegetables', 'whole milk', 'pastry'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'pip fruit', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'butter', 'pork', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'butter', 'root vegetables', 'other vegetables', 'rolls/buns'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'root vegetables', 'other vegetables', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'root vegetables', 'other vegetables', 'whole milk'})
# SUPPORT:	0.004168784951703101
# RULE:	frozenset({'butter', 'other vegetables', 'whole milk', 'sausage'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'tropical fruit', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'tropical fruit', 'other vegetables', 'whole milk'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'tropical fruit', 'yogurt', 'other vegetables'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'whipped/sour cream', 'other vegetables', 'whole milk'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'butter', 'yogurt', 'other vegetables', 'whole milk'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'butter', 'root vegetables', 'whole milk', 'rolls/buns'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter', 'root vegetables', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'butter', 'root vegetables', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter', 'root vegetables', 'yogurt', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'butter', 'tropical fruit', 'yogurt', 'whole milk'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'butter', 'whipped/sour cream', 'yogurt', 'whole milk'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter milk', 'nan', 'other vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter milk', 'nan', 'other vegetables', 'pip fruit'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'butter milk', 'nan', 'whipped/sour cream', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'butter milk', 'nan', 'whole milk', 'pip fruit'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'butter milk', 'nan', 'whipped/sour cream', 'whole milk'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'butter milk', 'yogurt', 'other vegetables', 'whole milk'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'nan', 'yogurt', 'candy'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'canned beer', 'shopping bags', 'nan', 'sausage'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'other vegetables', 'cat food'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'yogurt', 'other vegetables', 'cat food'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'root vegetables', 'citrus fruit', 'chicken'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'nan', 'yogurt', 'citrus fruit', 'chicken'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'domestic eggs', 'nan', 'root vegetables', 'chicken'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'domestic eggs', 'nan', 'whole milk', 'chicken'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'domestic eggs', 'other vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'nan', 'hamburger meat', 'other vegetables', 'chicken'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'nan', 'other vegetables', 'chicken', 'pip fruit'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'other vegetables', 'chicken', 'sausage'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'tropical fruit', 'nan', 'root vegetables', 'chicken'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'root vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.005897305541433655
# RULE:	frozenset({'nan', 'yogurt', 'root vegetables', 'chicken'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'nan', 'whipped/sour cream', 'whole milk', 'chicken'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'nan', 'whipped/sour cream', 'yogurt', 'chicken'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'whole milk', 'other vegetables', 'rolls/buns', 'chicken'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'whipped/sour cream', 'other vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'yogurt', 'other vegetables', 'whole milk', 'chicken'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'chocolate', 'nan', 'other vegetables', 'fruit/vegetable juice'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'chocolate', 'nan', 'yogurt', 'fruit/vegetable juice'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'chocolate', 'nan', 'long life bakery product', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'chocolate', 'nan', 'long life bakery product', 'whole milk'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'chocolate', 'nan', 'tropical fruit', 'pastry'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'tropical fruit', 'nan', 'citrus fruit', 'curd'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'yogurt', 'citrus fruit', 'curd'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'domestic eggs', 'citrus fruit', 'whole milk', 'other vegetables'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'root vegetables', 'citrus fruit', 'frozen vegetables'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'nan', 'root vegetables', 'citrus fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'nan', 'citrus fruit', 'fruit/vegetable juice', 'soda'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'tropical fruit', 'nan', 'citrus fruit', 'fruit/vegetable juice'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'fruit/vegetable juice', 'other vegetables'})
# SUPPORT:	0.002338586680223691
# ...
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'domestic eggs', 'other vegetables', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'domestic eggs', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'domestic eggs', 'root vegetables', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'domestic eggs', 'yogurt', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'frankfurter', 'other vegetables', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'frankfurter', 'nan', 'other vegetables', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'frankfurter', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'frankfurter', 'rolls/buns', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'frankfurter', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'whole milk', 'frozen vegetables', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'frozen vegetables', 'nan'})
# SUPPORT:	0.003863751906456533
# RULE:	frozenset({'nan', 'other vegetables', 'whole milk', 'frozen vegetables', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'whole milk', 'frozen vegetables', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'yogurt', 'frozen vegetables', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'yogurt', 'whole milk', 'frozen vegetables', 'nan'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'root vegetables', 'nan', 'whole milk', 'frozen vegetables', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'pip fruit', 'yogurt', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'fruit/vegetable juice', 'tropical fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'other vegetables', 'fruit/vegetable juice', 'whole milk', 'nan'})
# SUPPORT:	0.003965429588205389
# RULE:	frozenset({'root vegetables', 'other vegetables', 'fruit/vegetable juice', 'yogurt', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'nan', 'other vegetables', 'fruit/vegetable juice', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'nan', 'other vegetables', 'fruit/vegetable juice', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'yogurt', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'other vegetables', 'fruit/vegetable juice', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'fruit/vegetable juice', 'pip fruit', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'fruit/vegetable juice', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'soda', 'fruit/vegetable juice', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'nan', 'fruit/vegetable juice', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'root vegetables', 'herbs', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'yogurt', 'whole milk', 'nan', 'long life bakery product'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'nan', 'margarine'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'napkins', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'newspapers', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'newspapers', 'nan', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'oil', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'oil', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'onions', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'onions', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'pip fruit', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'pastry', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'whole milk', 'pastry', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'yogurt', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'pork', 'other vegetables', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'pip fruit', 'tropical fruit'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'other vegetables', 'pip fruit', 'whole milk', 'nan'})
# SUPPORT:	0.005490594814438231
# RULE:	frozenset({'root vegetables', 'other vegetables', 'pip fruit', 'yogurt', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'nan', 'other vegetables', 'pip fruit', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'nan', 'other vegetables', 'pip fruit', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'nan', 'other vegetables', 'pip fruit', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'other vegetables', 'pip fruit', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'other vegetables', 'pip fruit', 'yogurt', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'pip fruit', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'rolls/buns', 'pork', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'root vegetables', 'pork', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'pork', 'other vegetables', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'pork', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'nan', 'other vegetables', 'tropical fruit'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'whole milk', 'nan'})
# SUPPORT:	0.006100660904931368
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'yogurt', 'nan'})
# SUPPORT:	0.004067107269954245
# RULE:	frozenset({'rolls/buns', 'nan', 'other vegetables', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'rolls/buns', 'other vegetables', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'root vegetables', 'other vegetables', 'sausage', 'whole milk', 'nan'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'other vegetables', 'shopping bags', 'whole milk', 'nan'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'other vegetables', 'sliced cheese', 'whole milk', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'soda', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'other vegetables', 'soda', 'whole milk', 'nan'})
# SUPPORT:	0.004473817996949669
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.003253685815963396
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.006914082358922217
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.004880528723945094
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.005083884087442806
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.003355363497712252
# RULE:	frozenset({'root vegetables', 'other vegetables', 'whole milk', 'nan', 'white bread'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.007727503812913066
# RULE:	frozenset({'other vegetables', 'soda', 'sausage', 'yogurt', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'other vegetables', 'sausage', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'other vegetables', 'soda', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0028469750889679717
# RULE:	frozenset({'nan', 'other vegetables', 'whole milk', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.004372140315200813
# RULE:	frozenset({'nan', 'other vegetables', 'yogurt', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'nan', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0075241484494153535
# RULE:	frozenset({'other vegetables', 'yogurt', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.005490594814438231
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'yogurt', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'sausage', 'yogurt', 'whole milk', 'pastry', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'nan', 'yogurt', 'whole milk', 'pastry', 'tropical fruit'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'nan', 'pip fruit', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'nan', 'pip fruit', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'pip fruit', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'pip fruit', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'sausage', 'pip fruit', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'pip fruit', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0037620742247076767
# RULE:	frozenset({'pip fruit', 'yogurt', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'nan', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0036603965429588205
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'nan', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0027452974072191155
# RULE:	frozenset({'rolls/buns', 'soda', 'sausage', 'shopping bags', 'nan'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'rolls/buns', 'nan', 'soda', 'yogurt', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'rolls/buns', 'nan', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.004778851042196238
# RULE:	frozenset({'rolls/buns', 'yogurt', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0029486527707168276
# RULE:	frozenset({'root vegetables', 'nan', 'sausage', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'sausage', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.00315200813421454
# RULE:	frozenset({'root vegetables', 'nan', 'whole milk', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.0026436197254702592
# RULE:	frozenset({'root vegetables', 'nan', 'yogurt', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'nan', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.005592272496187087
# RULE:	frozenset({'root vegetables', 'yogurt', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'nan', 'sausage', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'nan', 'yogurt', 'whole milk', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.004270462633451958
# RULE:	frozenset({'root vegetables', 'other vegetables', 'pip fruit', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'other vegetables', 'pip fruit', 'yogurt', 'whole milk'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'other vegetables', 'pip fruit', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'yogurt', 'whole milk'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'rolls/buns', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002541942043721403
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0035587188612099642
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'whole milk', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'other vegetables', 'yogurt', 'whole milk', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'other vegetables', 'butter', 'yogurt', 'whole milk', 'tropical fruit', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'nan', 'other vegetables', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.003050330452465684
# RULE:	frozenset({'root vegetables', 'citrus fruit', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'citrus fruit', 'nan', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'pip fruit', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'other vegetables', 'pip fruit', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'nan', 'other vegetables', 'pip fruit', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'root vegetables', 'rolls/buns', 'other vegetables', 'yogurt', 'whole milk', 'nan'})
# SUPPORT:	0.002338586680223691
# RULE:	frozenset({'rolls/buns', 'nan', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.002440264361972547
# RULE:	frozenset({'root vegetables', 'nan', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit'})
# SUPPORT:	0.0034570411794611084
# RULE:	frozenset({'root vegetables', 'other vegetables', 'yogurt', 'whole milk', 'nan', 'whipped/sour cream'})
# SUPPORT:	0.0022369089984748346
# RULE:	frozenset({'nan', 'other vegetables', 'yogurt', 'whole milk', 'tropical fruit', 'whipped/sour cream'})
# SUPPORT:	0.002338586680223691

# %% [markdown]
# RULE 1: \t fro
# zenset({'Instant food products', 'hamburger meat'})\nSUPPORT:\t0.003050330452465684
#
# If a customer buys "Instant food products" and "hamburger meat", then there is a support of 0.00305, which means that these items are purchased together in approximately 0.305% of all transactions.

# %% [markdown]
# > ### Applying apriori algorithm on working people's dataset

# %%
#importing data.csv
columns = ["age","workClass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","income"]
data = pd.read_csv("DATA.csv",names=columns)
data.head()
# Out:
#    age          workClass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data = data.head(1000)

# %%
print(data.columns)
data.shape
# Out:
# Index(['age', 'workClass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')
# (1000, 15)

# %% [markdown]
# > ### Data Preprocessing

# %%
data.dropna(axis = 0, subset =['native-country'], inplace = True)
data['native-country'] = data['native-country'].astype('str')
data = data[~data['native-country'].str.contains("\?")]

missing_values =data.isna().sum()
print("Missing values: \n",missing_values)
# Out:
# Missing values:
#  age               0
# workClass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64
# <>:3: DeprecationWarning: invalid escape sequence \?
# <>:3: DeprecationWarning: invalid escape sequence \?
# <>:3: DeprecationWarning: invalid escape sequence \?
# C:\Users\Hamza\AppData\Local\Temp\ipykernel_11156\3170812793.py:3: DeprecationWarning: invalid escape sequence \?
#   data = data[~data['native-country'].str.contains("\?")]

# %%
data.shape
# Out:
# (982, 15)

# %%
data.head()
# Out:
#    age          workClass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data_rows = []
for i in range(0, 982):
    data_rows.append([str(data.values[i,u]) for u in range(0, 15)])

# %% [markdown]
# > ### Optimizing results rules of apriori data

# %% [markdown]
# #### Ranking top 10 rules based on support and confidence combination.

# %%
rule = apriori(data_rows, min_support=0.3, min_confidence=0.6)
sorted_rules = sorted(rule, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]
for rule1 in sorted_rules:
    lhs = ', '.join(rule1.ordered_statistics[0].items_base)
    rhs = ', '.join(rule1.ordered_statistics[0].items_add)
    confidence = rule1.ordered_statistics[0].confidence
    support = rule1.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  Female -> 0
# Confidence: 1.0
# Support: 0.33095723014256617
# Rule:  HS-grad -> 0
# Confidence: 1.0
# Support: 0.32179226069246436
# Rule:  HS-grad -> 9
# Confidence: 1.0
# Support: 0.32179226069246436
# Rule:  Husband ->  Male
# Confidence: 1.0
# Support: 0.37169042769857435
# Rule:  Husband ->  Married-civ-spouse
# Confidence: 1.0
# Support: 0.37169042769857435
# Rule:  Husband -> 0
# Confidence: 1.0
# Support: 0.37169042769857435
# Rule:  Married-civ-spouse -> 0
# Confidence: 1.0
# Support: 0.4378818737270876
# Rule:  Never-married -> 0
# Confidence: 1.0
# Support: 0.34826883910386963
# Rule: 40 -> 0
# Confidence: 1.0
# Support: 0.48268839103869654

# %% [markdown]
# These rules are generated on min_support 0.3 and confidence of 0.6 , therefore the output has all relations that achieve these rules. Apriori is beneficial as it generates best itemsets on confidence and support count basis.
#
# Usefull:
# 1. Rule: -> 0
# Description: This rule indicates that all instances in the dataset have the target variable set to 0, with a confidence of 1.0 and support of 1.0. This rule suggests a strong association with the majority class.
# 2. Rule: Female -> 0
# Description: This rule shows that all instances where the gender is Female have the target variable set to 0, with a confidence of 1.0 and support of 0.334. This rule suggests a strong association between being female and the target variable.
# 3. Rule: HS-grad -> 0
# Description: This rule indicates that all instances with an education level of HS-grad have the target variable set to 0, with a confidence of 1.0 and support of 0.314. This rule suggests a strong association between having a high school education and the target variable.
# 4. Rule: Husband -> Male
# Description: This rule shows that all instances where the relationship status is Husband are associated with the gender Male, with a confidence of 1.0 and support of 0.378. This rule indicates a strong association between being a husband and being male.
# 5. Rule: Husband -> Married-civ-spouse
# Description: This rule indicates that all instances where the relationship status is Husband are associated with the marital status Married-civ-spouse, with a confidence of 1.0 and support of 0.378. This rule suggests a strong association between being a husband and having a civilian spouse.
# 6. Rule: Married-civ-spouse -> 0
# Description: This rule shows that all instances with the marital status Married-civ-spouse have the target variable set to 0, with a confidence of 1.0 and support of 0.452. This rule suggests a strong association between being a civilian spouse and the target variable.
# 7. Rule: Never-married -> 0
# Description: This rule indicates that all instances with the marital status Never-married have the target variable set to 0, with a confidence of 1.0 and support of 0.34. This rule suggests a strong association between being never married and the target variable.
# 8. Rule: 40 -> 0
# Description: This rule shows that all instances with an age of 40 have the target variable set to 0, with a confidence of 1.0 and support of 0.53. This rule suggests a strong association between being 40 years old and the target variable.

# %%
rule2 = apriori(data_rows, min_support=0.5, min_confidence=0.5)
sorted_rules = sorted(rule2, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]

for rule2 in sorted_rules:
    lhs = ', '.join(rule2.ordered_statistics[0].items_base)
    rhs = ', '.join(rule2.ordered_statistics[0].items_add)
    confidence = rule2.ordered_statistics[0].confidence
    support = rule2.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  ->  United-States
# Confidence: 0.9185336048879837
# Support: 0.9185336048879837
# Rule:  ->  United-States, 0
# Confidence: 0.9185336048879837
# Support: 0.9185336048879837
# Rule:  ->  White
# Confidence: 0.8482688391038696
# Support: 0.8482688391038696
# Rule:  ->  White, 0
# Confidence: 0.8482688391038696
# Support: 0.8482688391038696
# Rule:  ->  United-States,  White
# Confidence: 0.7922606924643585
# Support: 0.7922606924643585
# Rule:  ->  United-States,  White, 0
# Confidence: 0.7922606924643585
# Support: 0.7922606924643585
# Rule:  ->  <=50K
# Confidence: 0.769857433808554
# Support: 0.769857433808554
# Rule:  ->  <=50K, 0
# Confidence: 0.769857433808554
# Support: 0.769857433808554
# Rule:  ->  <=50K,  United-States
# Confidence: 0.7057026476578412
# Support: 0.7057026476578412

# %% [markdown]
# 1. Rule: -> 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K or >50K) and the 0 value, which is the majority class in the dataset. This rule has a confidence of 1.0 and support of 1.0, meaning that all instances in the dataset with this pattern have the target variable set to <=50K.
# 2. Rule:  -> United-States
# Explanation: This rule shows that there is a strong association between the country of origin (United-States) and the target variable. The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# 3. Rule:  -> 0, United-States
# Explanation: This rule indicates that there is a strong association between the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# 4. Rule:  -> White
# Explanation: This rule shows that there is a strong association between the race (White) and the target variable. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# 5. Rule:  -> White, 0
# Explanation: This rule indicates that there is a strong association between the race (White) and the 0 value, the majority class. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
# 6. Rule:  -> <=50K
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and itself. This rule has a confidence of 0.782 and support of 0.782, meaning that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# 6. Rule:  -> <=50K, 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K) and the 0 value, the majority class. The confidence of 0.782 indicates that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# 7. Rule:  -> White, United-States
# Explanation: This rule shows that there is a strong association between the race (White) and the country of origin (United-States) and the target variable. The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# 8. Rule:  -> White, 0, United-States
# Explanation: This rule indicates that there is a strong association between the race (White), the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
# 9. Rule:  -> <=50K, United-States
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and the country of origin (United-States) and the target variable. The confidence of 0.708 indicates that 70.8% of instances in the dataset with this pattern have the target variable set to <=50K.

# %%
rules = apriori(data_rows, min_support=0.5, min_confidence=0.2)
sorted_rules = sorted(rules, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]

for rule in sorted_rules:
    lhs = ', '.join(rule.ordered_statistics[0].items_base)
    rhs = ', '.join(rule.ordered_statistics[0].items_add)
    confidence = rule.ordered_statistics[0].confidence
    support = rule.support
    print(f"Rule: {lhs} -> {rhs}")
    print(f"Confidence: {confidence}")
    print(f"Support: {support}")
# Out:
# Rule:  -> 0
# Confidence: 1.0
# Support: 1.0
# Rule:  ->  United-States
# Confidence: 0.9185336048879837
# Support: 0.9185336048879837
# Rule:  ->  United-States, 0
# Confidence: 0.9185336048879837
# Support: 0.9185336048879837
# Rule:  ->  White
# Confidence: 0.8482688391038696
# Support: 0.8482688391038696
# Rule:  ->  White, 0
# Confidence: 0.8482688391038696
# Support: 0.8482688391038696
# Rule:  ->  United-States,  White
# Confidence: 0.7922606924643585
# Support: 0.7922606924643585
# Rule:  ->  United-States,  White, 0
# Confidence: 0.7922606924643585
# Support: 0.7922606924643585
# Rule:  ->  <=50K
# Confidence: 0.769857433808554
# Support: 0.769857433808554
# Rule:  ->  <=50K, 0
# Confidence: 0.769857433808554
# Support: 0.769857433808554
# Rule:  ->  <=50K,  United-States
# Confidence: 0.7057026476578412
# Support: 0.7057026476578412

# %% [markdown]
# 1. Rule: -> 0
# Confidence: 1.0
# Support: 1.0
# Explanation: This rule indicates that whenever the antecedent is present, the consequent '0' is always present with 100% confidence and support. This rule essentially represents a single itemset without any specific association.
# 2. Rule: -> United-States
# Confidence: 0.9081632653061225
# Support: 0.9081632653061225
# Explanation: This rule suggests that when there's no specific antecedent, the consequent 'United-States' is present with a high confidence of approximately 91% and support of approximately 91%.
# 3. Rule: -> United-States, 0
# Confidence: 0.9081632653061225
# Support: 0.9081632653061225
# Explanation: Similar to the previous rule, but here the consequent is 'United-States' along with '0', and the confidence and support values are the same.
# 4. Rule: -> White
# Confidence: 0.8367346938775511
# Support: 0.8367346938775511
# Explanation: When there's no specific antecedent, the consequent 'White' is present with a confidence of approximately 83.67% and support of approximately 83.67%.
# 5. Rule: -> White, 0
# Confidence: 0.8367346938775511
# Support: 0.8367346938775511
# Explanation: Similar to the previous rule, but here the consequent is 'White' along with '0', and the confidence and support values are the same.
# 6. Rule: -> <=50K
# Confidence: 0.7775510204081633
# Support: 0.7775510204081633
# Explanation: When there's no specific antecedent, the consequent '<=50K' is present with a confidence of approximately 77.76% and support of approximately 77.76%.
# 7. Rule: -> <=50K, 0
# Confidence: 0.7775510204081633
# Support: 0.7775510204081633
# Explanation: Similar to the previous rule, but here the consequent is '<=50K' along with '0', and the confidence and support values are the same.
# 8. Rule: -> United-States, White
# Confidence: 0.7755102040816326
# Support: 0.7755102040816326
# Explanation: When there's no specific antecedent, the consequents 'United-States' and 'White' are present together with a confidence of approximately 77.55% and support of approximately 77.55%.
# 9. Rule: -> United-States, White, 0
# Confidence: 0.7755102040816326
# Support: 0.7755102040816326
# Explanation: Similar to the previous rule, but here the consequents are 'United-States', 'White', and '0', and the confidence and support values are the same.
# 10. Rule: -> <=50K, United-States
# Confidence: 0.7061224489795919
# Support: 0.7061224489795919
# Explanation: When there's no specific antecedent, the consequents '<=50K' and 'United-States' are present together with a confidence of approximately 70.61% and support of approximately 70.61%.

# %% [markdown]
# > #### Rank best 10 relations based on interest ,combination of interest and support

# %%
min_support_ranges = [
    (0.5,0.2),(0.6,0.2),(0.8,0.4) #min_support,min_interest
]
for min_interest,min_support in min_support_ranges:
    rules = apriori(data_rows, min_support=min_support, min_confidence=0.3)
    # sorted_rules = sorted(rules, key=lambda rule: rule.ordered_statistics[0].confidence, reverse=True)[:10]
    for rule in rules:
        support_lhs = rule.support
        support_rhs = rule.ordered_statistics[0].items_add
        support_rhs = data[data['income'] == ' <=50K'].shape[0] / len(data_rows)
        interest = support_lhs * (rule.ordered_statistics[0].confidence - support_rhs)
        rule.interest = interest
        
    sorted_rules = sorted(rules, key=lambda rule: rule.interest, reverse=True)[:10]#top 10 rank based on interest
    
    for rule in sorted_rules:
        lhs = ', '.join(rule.ordered_statistics[0].items_base)
        rhs = ', '.join(rule.ordered_statistics[0].items_add)
        confidence = rule.ordered_statistics[0].confidence
        support = rule.support
        lhs = rule.ordered_statistics[0].items_base
        rhs = rule.ordered_statistics[0].items_add
        support_lhs = data[lhs].sum() / 500
        support_rhs = data[rhs].sum() / 500
        interest = support_lhs * (confidence - support_rhs)
        rule.interest = interest
        print(f"Rule: {lhs} -> {rhs}")
        print(f"Confidence: {confidence}")
        print(f"Support: {support}")

# %% [markdown]
# ## Association Rules Interset Insights:
#
# 1. Rule: -> 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K or >50K) and the 0 value, which is the majority class in the dataset. This rule has a confidence of 1.0 and support of 1.0, meaning that all instances in the dataset with this pattern have the target variable set to <=50K.
#
# 2. Rule:  -> United-States
# Explanation: This rule shows that there is a strong association between the country of origin (United-States) and the target variable. The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 3. Rule:  -> 0, United-States
# Explanation: This rule indicates that there is a strong association between the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.906 indicates that 90.6% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 4. Rule:  -> White
# Explanation: This rule shows that there is a strong association between the race (White) and the target variable. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 5. Rule:  -> White, 0
# Explanation: This rule indicates that there is a strong association between the race (White) and the 0 value, the majority class. The confidence of 0.836 indicates that 83.6% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 6. Rule:  -> <=50K
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and itself. This rule has a confidence of 0.782 and support of 0.782, meaning that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 7. Rule:  -> <=50K, 0
# Explanation: This rule indicates that there is a strong association between the target variable (<=50K) and the 0 value, the majority class. The confidence of 0.782 indicates that 78.2% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 8. Rule:  -> White, United-States
# Explanation: This rule shows that there is a strong association between the race (White) and the country of origin (United-States) and the target variable. The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 9. Rule:  -> White, 0, United-States
# Explanation: This rule indicates that there is a strong association between the race (White), the 0 value, the majority class, and the country of origin (United-States). The confidence of 0.772 indicates that 77.2% of instances in the dataset with this pattern have the target variable set to <=50K.
#
# 10. Rule:  -> <=50K, United-States
# Explanation: This rule shows that there is a strong association between the target variable (<=50K) and the country of origin (United-States) and the target variable. The confidence of 0.708 indicates that 70.8% of instances in the dataset with this pattern have the target variable set to <=50K.

# %% [markdown]
# # Questions:
# 1. Age and Hours Worked Association:
# Rule: {age>40} -> {hours-per-week>40}
# Explanation: This rule could suggest that individuals above the age of 40 tend to work more than 40 hours per week.
#
# 2. Gender and Occupation Association:
# Rule: {sex=Female} -> {occupation=Adm-clerical}
# Explanation: This rule might show a common association between females and administrative or clerical occupations.
#
# 3. Education and Income Association:
# Rule: {education-num>12} -> {income=>50K}
# Explanation: This rule could indicate that individuals with education levels above 12 have a higher likelihood of earning above $50K.
