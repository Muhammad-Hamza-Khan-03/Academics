# %%
import pandas as pd

# %%
df = pd.read_excel("FSC.xlsx",header =True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df = pd.read_excel("FSC.xlsx",header =True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.head()
# Out:
#   FAST School of Computing TIME TABLE Spring 2024 <v1.1>    Unnamed: 1  \
# 0                                        Color Codes               NaN
# 1                                            Periods               NaN
# 2                                               Days              Room
# 3              Monday                 Monday              Seminar Hall
# 4                                                NaN            NB-201
#
#   Unnamed: 2  Unnamed: 3  Unnamed: 4                      Unnamed: 5  \
# 0        NaN         NaN         NaN                        BDS-2023
# 1         10        20.0        30.0                              40
# 2  8:00 a.m.         NaN         NaN                             NaN
# 3        NaN         NaN         NaN  Multivariate Calculus (BCS-2H)
# 4        NaN         NaN         NaN       Database Systems (BCS-4F)
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  Unnamed: 72  \
# ...
